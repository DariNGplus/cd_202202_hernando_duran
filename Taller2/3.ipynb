# %% [markdown]
# <a href="https://colab.research.google.com/github/DariNGplus/cd_202202_hernando_duran/blob/main/Taller2/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyproj
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.3 MB 6.2 MB/s
# ...

# %%
import pandas as pd

route = 'https://foscalinternacional.com/datasets/eventos_dengue_2020.csv'
df = pd.read_csv(route)

# %%
df
# Out:
#         ID     fec_not  semana   año  edad_  uni_med_ sexo_  cod_pais_o  \
# 0        1  17/01/2020       1  2020     25         1     F         170
# 1        2  10/01/2020       1  2020     24         1     M         170
# 2        3  12/01/2020       1  2020     58         1     M         170
# 3        4  12/01/2020       1  2020     29         1     F         170
# 4        5  10/01/2020       1  2020     56         1     F         170
# ...    ...         ...     ...   ...    ...       ...   ...         ...
# 1257  1258   7/03/2020       9  2020     36         1     F         170
# 1258  1259  13/03/2020       9  2020     42         1     M         170
# 1259  1260   8/03/2020       9  2020      2         1     M         170
# 1260  1261  11/03/2020       9  2020     12         1     F         170
# 1261  1262   9/03/2020       9  2020     14         1     M         170
#
#       cod_dpto_o  cod_mun_o  ...  hipotension  hepatomegalia  \
# ...

# %%
df.dtypes
# Out:
# ID                     int64
# fec_not               object
# semana                 int64
# año                    int64
# edad_                  int64
# uni_med_               int64
# sexo_                 object
# cod_pais_o             int64
# cod_dpto_o             int64
# cod_mun_o              int64
# area_                  int64
# ocupacion_             int64
# tip_ss_               object
# cod_ase_              object
# gp_discapa             int64
# gp_desplaz             int64
# gp_migrant             int64
# gp_carcela             int64
# gp_gestan              int64
# gp_calle               int64
# gp_psiquia             int64
# gp_vic_vio             int64
# fecha_contagio        object
# inicio_sintomas       object
# pac_hos_               int64
# fec_hos_              object
# condicion_final        int64
# fecha_defuncion      float64
# fecha_nacimiento      object
# certif_defuncion     float64
# familiar_sintomas      int64
# fiebre                 int64
# ...

# %%
from datetime import datetime

df['fec_not2'] = pd.to_datetime(df['fec_not'], format= "%d/%m/%Y")
df['fec_hos_2'] = pd.to_datetime(df['fec_hos_'], format= "%d/%m/%Y")
df['fecha_contagio2'] = pd.to_datetime(df['fecha_contagio'], format= "%d/%m/%Y")
df['inicio_sintomas2'] = pd.to_datetime(df['inicio_sintomas'], format= "%d/%m/%Y")

# %%
import pyproj

P = pyproj.Proj(proj='utm', zone = 18, ellps='WGS84', preserve_units=True)

# %%
df['x'], df['y'] = P(df['longitud'], df['latitud'])


df
# Out:
#         ID     fec_not  semana   año  edad_  uni_med_ sexo_  cod_pais_o  \
# 0        1  17/01/2020       1  2020     25         1     F         170
# 1        2  10/01/2020       1  2020     24         1     M         170
# 2        3  12/01/2020       1  2020     58         1     M         170
# 3        4  12/01/2020       1  2020     29         1     F         170
# 4        5  10/01/2020       1  2020     56         1     F         170
# ...    ...         ...     ...   ...    ...       ...   ...         ...
# 1257  1258   7/03/2020       9  2020     36         1     F         170
# 1258  1259  13/03/2020       9  2020     42         1     M         170
# 1259  1260   8/03/2020       9  2020      2         1     M         170
# 1260  1261  11/03/2020       9  2020     12         1     F         170
# 1261  1262   9/03/2020       9  2020     14         1     M         170
#
#       cod_dpto_o  cod_mun_o  ...  aum_hematocrito                 conducta  \
# ...

# %%
import math

alc = [7.06304, -73.08619]
alc = P(alc[1], alc[0])

dist_alc = []

for i in range(df.shape[0]):
  dist_alc.append(math.sqrt((df['x'].iloc[i]-alc[0])**2 + (df['y'].iloc[i] - alc[1])**2))

df['dist_alc'] = dist_alc

# %%
df
# Out:
#         ID     fec_not  semana   año  edad_  uni_med_ sexo_  cod_pais_o  \
# 0        1  17/01/2020       1  2020     25         1     F         170
# 1        2  10/01/2020       1  2020     24         1     M         170
# 2        3  12/01/2020       1  2020     58         1     M         170
# 3        4  12/01/2020       1  2020     29         1     F         170
# 4        5  10/01/2020       1  2020     56         1     F         170
# ...    ...         ...     ...   ...    ...       ...   ...         ...
# 1257  1258   7/03/2020       9  2020     36         1     F         170
# 1258  1259  13/03/2020       9  2020     42         1     M         170
# 1259  1260   8/03/2020       9  2020      2         1     M         170
# 1260  1261  11/03/2020       9  2020     12         1     F         170
# 1261  1262   9/03/2020       9  2020     14         1     M         170
#
#       cod_dpto_o  cod_mun_o  ...                 conducta   latitud  \
# ...

# %%
import numpy

bw = 100
res = 10

xmin = df['x'].min() - bw
xmax = df['x'].max() + bw

ymin = df['y'].min() - bw
ymax = df['y'].max() + bw

rows = int(math.ceil(ymax-ymin)/res)

cols = int(math.ceil(xmax-xmin)/res)

map = numpy.zeros((cols, rows))
amap = numpy.zeros((cols, rows))

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

for i in range(df.shape[0]):
  curRow = int(math.floor((df['y'].iloc[i] - ymin)/res))
  curCol = int(math.floor((df['x'].iloc[i] - xmin)/res))
  ##print( str(curRow)+ " , " +str(curCol))
  map[curCol, curRow] += 1

# %%
rows
# Out:
# 475

# %%
def kde_quartic(d,h):
    dn=d/h
    P=(15/16)*(1-dn**2)**2
    return P

# %%
amap = numpy.zeros((cols, rows))

for i in range(0, len(amap)):
  for j in range(0, len(amap[i])):
    for k in range(max(0, int(i-(bw/res))), min(cols, int(i+(bw/res)))):
      for l in range(max(0, int(j-(bw/res))), min(rows, int(j+(bw/res)))):
        d = math.sqrt((k-i)**2 + (l-j)**2)
        amap[i][j] += map[k][l] * kde_quartic(d, bw)

# %%
import seaborn as sns
import matplotlib.pylab as plt
from matplotlib.pyplot import figure

figure(figsize=(12, 10), dpi=100)

ax = sns.heatmap(amap.T)

plt.show()
